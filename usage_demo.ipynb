# %%
from scraper_functions import *
# Out:
# Done, the environment is ready. Now Teach Me Scrape!

# %%
data, path = scrape_what_from_where('Advanced Ophthalmic','https://engineering.nyu.edu/research/labs-and-groups', go_up = 2)
data
# Out:
# [Success] The website at "https://engineering.nyu.edu/research/labs-and-groups" is collected successfully.
#
# Unique match is found:
# <span class="field field--name-title field--type-string field--label-hidden">Advanced Ophthalmic Ima ......
#
#
#
# Extracting contents ...
#
#
# [Success] The selector path used to extract contents is:
#
# ...
